# %% [markdown]
# ### imports

# %%
from collections import defaultdict
import re

import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import jaccard_score

# %% [markdown]
# ### preprocessing data

# %%
df = pd.read_csv('./data/news.csv', sep=';')

# %%
sites = ['lenta', 'tass']

# %%
print(df.shape)
df.head()
# Out:
# (103176, 4)
#                                              url                       date  \
# 0  https://lenta.ru/news/2019/05/22/gotepisodes/  2019-05-22T17:36:00+03:00
# 1    https://lenta.ru/news/2019/01/09/challenge/  2019-01-09T18:16:00+03:00
# 2          https://lenta.ru/news/2019/01/29/x35/  2019-01-29T19:53:00+03:00
# 3         https://lenta.ru/news/2019/04/02/nato/  2019-04-02T10:52:00+03:00
# 4      https://lenta.ru/news/2019/02/01/frigate/  2019-02-01T19:05:00+03:00
#
#                                        news_headline  \
# 0              Названа лучшая серия «Игры престолов»
# 1  Россию причислили к «внешним вызовам» для Евро...
# 2  Создатель супероружия России признал ракетные ...
# 3  Прибалты захотели видеть у себя больше америка...
# 4                      Отверстие «Фрегата» устранили
#
#                                            news_body
# 0  Британское издание The Guardian составило рейт...
# 1  Заместитель председателя Европейской комиссии ...
# 2  Украина способна разрабатывать ракетное вооруж...
# 3  Эстония выступает за обеспечение регулярного р...
# 4  Микроотверстие, обнаруженное в российском разг...

# %%
tass_df = df[(df.url.apply(lambda row: 'tass' in row))].reset_index()

# %%
print(tass_df.shape)
tass_df.head()
# Out:
# (82965, 5)
#    index                                   url        date  \
# 0  20156         https://tass.ru/sport/6069789  1549035126
# 1  20157     https://tass.ru/ekonomika/1640098  1418297887
# 2  20158      https://tass.ru/politika/3472158  1469028708
# 3  20159     https://tass.ru/ekonomika/1194085  1400363544
# 4  20160  https://tass.ru/nedvizhimost/5738028  1540905058
#
#                                        news_headline  \
# 0  Кремлев: МОК и AIBA не обсуждают вопрос исключ...
# 1  Индекс РТС в середине четверга обновил минимум...
# 2  Яровая: антитеррористический пакет законов защ...
# 3  Hyundai отзывает с рынка США более 140 тыс. кр...
# 4  Мутко: правительство может разработать новый м...
#
#                                            news_body
# 0    АНАПА, 1 февраля. /ТАСС/. Международный олим...
# 1    МОСКВА, 11 декабря. /Корр. ТАСС Елена Кожухо...
# 2    МОСКВА, 20 июля. /ТАСС/. Антитеррористически...
# 3    НЬЮ-ЙОРК, 18 мая. /Корр. ИТАР-ТАСС Андрей Бе...
# 4    МОСКВА, 30 октября. /ТАСС/. Вице-премьер РФ ...

# %%
lenta_df = df[(df.url.apply(lambda row: 'lenta' in row))].reset_index()

# %%
print(lenta_df.shape)
lenta_df.head()
# Out:
# (20211, 5)
#    index                                            url  \
# 0      0  https://lenta.ru/news/2019/05/22/gotepisodes/
# 1      1    https://lenta.ru/news/2019/01/09/challenge/
# 2      2          https://lenta.ru/news/2019/01/29/x35/
# 3      3         https://lenta.ru/news/2019/04/02/nato/
# 4      4      https://lenta.ru/news/2019/02/01/frigate/
#
#                         date  \
# 0  2019-05-22T17:36:00+03:00
# 1  2019-01-09T18:16:00+03:00
# 2  2019-01-29T19:53:00+03:00
# 3  2019-04-02T10:52:00+03:00
# 4  2019-02-01T19:05:00+03:00
#
#                                        news_headline  \
# 0              Названа лучшая серия «Игры престолов»
# 1  Россию причислили к «внешним вызовам» для Евро...
# 2  Создатель супероружия России признал ракетные ...
# 3  Прибалты захотели видеть у себя больше америка...
# 4                      Отверстие «Фрегата» устранили
#
#                                            news_body
# 0  Британское издание The Guardian составило рейт...
# 1  Заместитель председателя Европейской комиссии ...
# 2  Украина способна разрабатывать ракетное вооруж...
# 3  Эстония выступает за обеспечение регулярного р...
# 4  Микроотверстие, обнаруженное в российском разг...

# %%
# get only 2000 news
lenta_df = lenta_df[lenta_df.index.isin(range(2000))]

# %%
# get only 2000 news
tass_df = tass_df[tass_df.index.isin(range(2000))]

# %%
news_df = pd.concat([tass_df, lenta_df], ignore_index=True)

# %%
print(news_df.shape)

news_df.head()
# Out:
# (4000, 5)
#    index                                   url        date  \
# 0  20156         https://tass.ru/sport/6069789  1549035126
# 1  20157     https://tass.ru/ekonomika/1640098  1418297887
# 2  20158      https://tass.ru/politika/3472158  1469028708
# 3  20159     https://tass.ru/ekonomika/1194085  1400363544
# 4  20160  https://tass.ru/nedvizhimost/5738028  1540905058
#
#                                        news_headline  \
# 0  Кремлев: МОК и AIBA не обсуждают вопрос исключ...
# 1  Индекс РТС в середине четверга обновил минимум...
# 2  Яровая: антитеррористический пакет законов защ...
# 3  Hyundai отзывает с рынка США более 140 тыс. кр...
# 4  Мутко: правительство может разработать новый м...
#
#                                            news_body
# 0    АНАПА, 1 февраля. /ТАСС/. Международный олим...
# 1    МОСКВА, 11 декабря. /Корр. ТАСС Елена Кожухо...
# 2    МОСКВА, 20 июля. /ТАСС/. Антитеррористически...
# 3    НЬЮ-ЙОРК, 18 мая. /Корр. ИТАР-ТАСС Андрей Бе...
# 4    МОСКВА, 30 октября. /ТАСС/. Вице-премьер РФ ...

# %%
def clear_new(new):
    return ' '.join(filter(lambda word: word != '', re.findall('[\w\d]*', new)))

# %%
texts_df = news_df.news_body.apply(clear_new)

# %%
texts_df.head()
# Out:
# 0    АНАПА 1 февраля ТАСС Международный олимпийский...
# 1    МОСКВА 11 декабря Корр ТАСС Елена Кожухова Рос...
# 2    МОСКВА 20 июля ТАСС Антитеррористический пакет...
# 3    НЬЮ ЙОРК 18 мая Корр ИТАР ТАСС Андрей Бекренев...
# 4    МОСКВА 30 октября ТАСС Вице премьер РФ Виталий...
# Name: news_body, dtype: object

# %% [markdown]
# ### Vectorizing text

# %%
BOW = defaultdict(lambda: [], {})

for num, row in tqdm_notebook(enumerate(texts_df)):
    words = row.split()
    for i in range(1, len(words)):
        BOW[' '.join([words[i - 1], words[i]])].append(num)
# Out:
# /Users/vitaly/PycharmProjects/chelgu_nlp_labs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
arr = np.zeros((texts_df.shape[0], len(BOW)), dtype=np.uint8)

for num, shingle in enumerate(BOW):
    arr[BOW[shingle], num] = 1

# %%
shingle_indexs = []

for num, i in enumerate(arr):
    shingle_indexs.append(i.nonzero()[0])

# %%
print(shingle_indexs[100])
# Out:
# [    2    19    20   195   196   211   492   666   796   803   804  1225
#   1487  2321  2615  2621  2622  2643  2703  2704  2711  2717  2720  2721
#   2722  2723  2724  2726  2730  2732  2733  2734  2735  2736  2737  2738
#   2739  2740  2741  2742  2743  2744  2745  2746  2747  2748  2749  2750
#   2753  2754  2755  2756  2757  2758  2759  2760  2761  2762  2763  2764
#   2765  2766  2776  2789  2790  2815  2921  2922  3030  3227  3245  3447
#   4420  4531  4543  4875  6984  8454  8600 10091 10092 12156 12771 13963
#  15352 15633 16739 18438 18948 20841 21183 22034 22035 22036 22037 22038
#  22039 22040 22041 22042 22043 22044 22045 22046 22047 22048 22049 22050
#  22051 22052 22053 22054 22055 22056 22057 22058 22059 22060 22061 22062
#  22063 22064 22065 22066 22067 22068 22069 22070 22071 22072 22073 22074
#  22075 22076 22077 22078 22079 22080 22081 22082 22083 22084 22085 22086
#  22087 22088 22089 22090 22091 22092 22093 22094 22095 22096 22097 22098
#  22099 22100 22101 22102 22103 22104 22105 22106 22107 22108 22109 22110
#  22111 22112 22113 22114 22115 22116 22117 22118 22119 22120 22121 22122
#  22123 22124 22125 22126 22127 22128 22129 22130 22131 22132 22133 22134
#  22135 22136 22137 22138 22139 22140 22141 22142 22143 22144 22145 22146
#  22147 22148 22149 22150 22151 22152 22153 22154 22155 22156 22157 22158
#  22159 22160 22161 22162 22163 22164 22165 22166 22167 22168 22169 22170
#  22171 22172 22173 22174 22175 22176 22177 22178 22179 22180 22181 22182
#  22183 22184 22185 22186 22187 22188 22189 22190 22191 22192 22193 22194
#  22195 22196 22197 22198 22199 22200 22201 22202 22203 22204 22205 22206
#  22207 22208 22209 22210 22211 22212 22213 22214 22215 22216 22217 22218
#  22219 22220 22221 22222 22223]

# %% [markdown]
# ### Calculating a nearest pairs

# %%
pairs = []

for i in tqdm_notebook(range(len(shingle_indexs))):
    max_ = 0
    max_index = 0
    for j in range(i + 1, len(shingle_indexs)):
        set1 = set(shingle_indexs[i])
        set2 = set(shingle_indexs[j])
        try:
            inter = len(set1.intersection(set2))
            union = len(set1.union(set2))
            jac = inter / union
        except ZeroDivisionError:
            continue
        if jac > max_:
            max_ = jac
            max_index = j
    
    pairs.append((i, max_index, jac))
# Out:
# /Users/vitaly/PycharmProjects/chelgu_nlp_labs/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0, max=4000.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b4d8a9fb936b> in <module>
#       5     max_index = 0
#       6     for j in range(i + 1, len(shingle_indexs)):
# ----> 7         set1 = set(shingle_indexs[i])
#       8         set2 = set(shingle_indexs[j])
#       9         try:
#
# KeyboardInterrupt:

# %%
pairs
# Out:
# [(0, 274, 0.004640371229698376),
#  (1, 1352, 0.0013123359580052493),
#  (2, 3977, 0.0),
#  (3, 183, 0.003663003663003663),
#  (4, 1845, 0.0029940119760479044),
#  (5, 1183, 0.0006891798759476223),
#  (6, 100, 0.0),
#  (7, 1123, 0.00980392156862745),
